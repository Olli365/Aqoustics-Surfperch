# %%
import os
import pandas as pd
import soundfile as sf
import time
from maad import sound
from maad.util import power2dB, format_features
from maad.rois import create_mask, select_rois
import numpy as np
import librosa
import tensorflow as tf
from tqdm import tqdm

# Load the pre-trained model
model_path = '/home/os/aqoustics/Aqoustics-Surfperch/kaggle'
model = tf.saved_model.load(model_path)

# Helper functions
def resample_and_split_audio(segment, original_sr, target_sr=32000):
    audio = librosa.resample(segment, orig_sr=original_sr, target_sr=target_sr)
    return audio

def process_audio_in_memory(segments, model, fs):
    rows_list = []
    target_sr = 32000
    target_length = 160000  # Target length of 5 seconds at 32 kHz

    for i, segment in enumerate(segments):
        try:
            # Resample the audio segment to match the target sample rate (32kHz)
            segment_resampled = resample_and_split_audio(segment, original_sr=fs)
            
            # Ensure the segment is exactly 160000 samples long
            if len(segment_resampled) > target_length:
                segment_resampled = segment_resampled[:target_length]  # Trim to target length
            elif len(segment_resampled) < target_length:
                segment_resampled = np.pad(segment_resampled, (0, target_length - len(segment_resampled)), 'constant')

            # Model expects batch dimension, so use np.newaxis to add it
            output = model.infer_tf(segment_resampled[np.newaxis, :])

            # Extract the embedding tensor
            embeddings = output['embedding']

            # Convert to numpy array
            embedding = embeddings.numpy()[0]

            row_data = {'segment_index': i + 1}
            for j, feature in enumerate(embedding):
                row_data[f'feature_{j}'] = feature
            rows_list.append(row_data)
        except Exception as e:
            print(f"An error occurred while processing segment {i}: {e}")
            continue

    return pd.DataFrame(rows_list)


# Update the process_audio function to pass fs to the process_audio_in_memory function
def process_audio(file_path, model):
    print(f"Processing file: {file_path}")
    start_time = time.time()

    try:
        # Load the audio file and get the sampling rate (fs)
        s, fs = sound.load(file_path)
    except Exception as e:
        print(f"Error loading file {file_path}: {e}")
        return pd.DataFrame()

    try:
        # Attempt to filter the signal
        s_filt = sound.select_bandwidth(s, fs, fcut=100, forder=3, ftype='highpass')
    except ValueError as e:
        print(f"Skipping file {file_path} due to filtering error: {e}")
        return pd.DataFrame()

    # Spectrogram parameters
    db_max = 70
    Sxx, tn, fn, ext = sound.spectrogram(s_filt, fs, nperseg=1024, noverlap=512)
    Sxx_db = power2dB(Sxx, db_range=db_max) + db_max

    # Background removal and smoothing
    Sxx_db_rmbg, _, _ = sound.remove_background(Sxx_db)
    Sxx_db_smooth = sound.smooth(Sxx_db_rmbg, std=1.25)
    im_mask = create_mask(im=Sxx_db_smooth, mode_bin='relative', bin_std=1.3, bin_per=0.8)
    im_rois, df_rois = select_rois(im_mask, min_roi=50, max_roi=None)

    if df_rois.empty:
        print(f"No ROIs found in file: {file_path}")
        return pd.DataFrame()

    # Format ROIs
    df_rois = format_features(df_rois, tn, fn)

    # Filter ROIs for those with centroid frequency below 2000Hz
    low_freq_rois = df_rois[df_rois['max_f'] <= 2000]
    print(low_freq_rois)

    if low_freq_rois.empty:
        print(f"No low frequency ROIs found in file: {file_path}")
        return pd.DataFrame()

    # Extract start and end times of the filtered ROIs
    low_freq_timestamps = low_freq_rois[['min_t', 'max_t']]
    low_freq_timestamps.columns = ['begin', 'end']

    # Generate in-memory 5-second audio segments
    audio_segments = []
    clip_duration = 5.0  # seconds

    for i, (start, end) in enumerate(low_freq_timestamps.itertuples(index=False)):
        mid_point = (start + end) / 2
        clip_start = max(0, mid_point - clip_duration / 2)
        clip_end = clip_start + clip_duration

        # Check if the clip is in the first 5 seconds or last 5 seconds of the audio
        if clip_start < 0:
            clip_start = 0
            clip_end = clip_duration
        elif clip_end > len(s) / fs:
            clip_end = len(s) / fs
            clip_start = clip_end - clip_duration

        start_sample = int(clip_start * fs)
        end_sample = int(clip_end * fs)
        audio_segment = s[start_sample:end_sample]
        audio_segments.append(audio_segment)

    # Process the segments with the model in-memory
    df_features = process_audio_in_memory(audio_segments, model, fs)

    # Print the number of features (rows) extracted
    print(f"Number of features found in {file_path}: {len(df_features)}")

    end_time = time.time()
    print(f"Finished processing file: {file_path}")

    return df_features

def process_folder(input_folder, output_folder, model):
    all_timestamps = []
    total_features = 0  # To count total features across all files
    for filename in os.listdir(input_folder):
        if filename.lower().endswith('.wav'):
            file_path = os.path.join(input_folder, filename)
            timestamps = process_audio(file_path, model)
            if not timestamps.empty:
                timestamps['file'] = filename
                all_timestamps.append(timestamps)
                total_features += len(timestamps)  # Count the features for each file

    if all_timestamps:
        # Concatenate all timestamps and save to CSV
        all_timestamps_df = pd.concat(all_timestamps, ignore_index=True)
        csv_path = os.path.join(output_folder, 'surfperch_feature_embeddings.csv')
        all_timestamps_df.to_csv(csv_path, index=False)
        print(f"CSV saved to {csv_path}")
        print(f"Total number of features extracted from all files: {total_features}")
        return all_timestamps_df
    else:
        print("No audio clips generated from any files.")
        return pd.DataFrame()

# %%
# Example usage
input_folder = '/mnt/d/Aqoustics/UMAP'
output_folder = '/mnt/d/Aqoustics/UMAP/output'
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

start_time = time.time()
all_timestamps = process_folder(input_folder, output_folder, model)
end_time = time.time()
print(f"Total processing time: {end_time - start_time:.2f} seconds")
# Out:
# Processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_120000.WAV
#   labelID    label  min_y  min_x  max_y  max_x    min_f   min_t     max_f  \
# 1       2  unknown     14   1324     29   1328  218.750  42.400   453.125
# 2       5  unknown     21   1671     33   1675  328.125  53.504   515.625
# 3       6  unknown     22   1285     35   1290  343.750  41.152   546.875
# 4       8  unknown     22   1471     38   1476  343.750  47.104   593.750
# 5       9  unknown     24    485     47    491  375.000  15.552   734.375
# 6      10  unknown     24   1097     35   1102  375.000  35.136   546.875
# 7      11  unknown     25    513     34    520  390.625  16.448   531.250
# 8      31  unknown     54   1285     66   1290  843.750  41.152  1031.250
# 9      32  unknown     54   1471     68   1475  843.750  47.104  1062.500
#
#     max_t
# 1  42.528
# 2  53.632
# 3  41.312
# 4  47.264
# 5  15.744
# 6  35.296
# 7  16.672
# 8  41.312
# 9  47.232
# W0000 00:00:1725452269.373877   56101 assert_op.cc:38] Ignoring Assert operator jax2tf_infer_fn_/assert_equal_1/Assert/AssertGuard/Assert
# Number of features found in /mnt/d/Aqoustics/UMAP/ind_D1_20220829_120000.WAV: 9
# Finished processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_120000.WAV
# Processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_120200.WAV
#    labelID    label  min_y  min_x  max_y  max_x     min_f   min_t     max_f  \
# 1        3  unknown     20    125     35    129   312.500   4.032   546.875
# 2        6  unknown     23    138     35    142   359.375   4.448   546.875
# 3        7  unknown     23    637     35    641   359.375  20.416   546.875
# 4        8  unknown     23    801     37    805   359.375  25.664   578.125
# 5        9  unknown     23   1003     35   1009   359.375  32.128   546.875
# 6       10  unknown     23   1532     37   1536   359.375  49.056   578.125
# 7       11  unknown     24    212     34    218   375.000   6.816   531.250
# 8       13  unknown     25    967     35    972   390.625  30.976   546.875
# 9       35  unknown     53    138     71    142   828.125   4.448  1109.375
# 10      36  unknown     53    637     72    641   828.125  20.416  1125.000
# 11      37  unknown     54    125     72    129   843.750   4.032  1125.000
# 14      45  unknown    112   1519    126   1523  1750.000  48.640  1968.750
#
#      max_t
# 1    4.160
# 2    4.576
# 3   20.544
# 4   25.792
# 5   32.320
# 6   49.184
# 7    7.008
# 8   31.136
# 9    4.576
# 10  20.544
# 11   4.160
# 14  48.768
# Number of features found in /mnt/d/Aqoustics/UMAP/ind_D1_20220829_120200.WAV: 12
# Finished processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_120200.WAV
# Processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_120400.WAV
#    labelID    label  min_y  min_x  max_y  max_x     min_f   min_t     max_f  \
# 1        2  unknown     18    422     31    427   281.250  13.536   484.375
# 2        3  unknown     21    174     39    180   328.125   5.600   609.375
# 3        4  unknown     23     63     36     70   359.375   2.048   562.500
# 4        5  unknown     23   1164     35   1168   359.375  37.280   546.875
# 5        7  unknown     25   1453     36   1461   390.625  46.528   562.500
# 6        8  unknown     25   1836     35   1840   390.625  58.784   546.875
# 7       19  unknown     53   1163     71   1169   828.125  37.248  1109.375
# 11      26  unknown    116    263    127    267  1812.500   8.448  1984.375
#
#      max_t
# 1   13.696
# 2    5.792
# 3    2.272
# 4   37.408
# 5   46.784
# 6   58.912
# 7   37.440
# 11   8.576
# Number of features found in /mnt/d/Aqoustics/UMAP/ind_D1_20220829_120400.WAV: 8
# Finished processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_120400.WAV
# Processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_120600.WAV
#    labelID    label  min_y  min_x  max_y  max_x     min_f   min_t     max_f  \
# 0        1  unknown      5   1701    116   1733    78.125  54.464  1812.500
# 1        2  unknown      6    731     14    782    93.750  23.424   218.750
# 3        8  unknown      7    441    112    451   109.375  14.144  1750.000
# 4        9  unknown      7    683     13    707   109.375  21.888   203.125
# 5       10  unknown      7    710     13    728   109.375  22.752   203.125
# 6       11  unknown      7    789     13    807   109.375  25.280   203.125
# 7       23  unknown      8    668     13    679   125.000  21.408   203.125
# 8       26  unknown      8   1771     15   1835   125.000  56.704   234.375
# 9       28  unknown      9    558     17    595   140.625  17.888   265.625
# 10      62  unknown     21    520     33    524   328.125  16.672   515.625
# 11      63  unknown     21    532     32    545   328.125  17.056   500.000
# 12      66  unknown     24    457     37    467   375.000  14.656   578.125
# 13      76  unknown     27    393     34    404   421.875  12.608   531.250
# 14     109  unknown     54     93     71     98   843.750   3.008  1109.375
# 15     110  unknown     54    195     70    200   843.750   6.272  1093.750
# 16     111  unknown     55     23     71     28   859.375   0.768  1109.375
# 17     112  unknown     58    744     69    748   906.250  23.840  1078.125
# 18     114  unknown     59    933     71    937   921.875  29.888  1109.375
# 23     120  unknown    114    654    126    658  1781.250  20.960  1968.750
#
#      max_t
# 0   55.488
# 1   25.056
# 3   14.464
# 4   22.656
# 5   23.328
# 6   25.856
# 7   21.760
# 8   58.752
# 9   19.072
# 10  16.800
# 11  17.472
# 12  14.976
# 13  12.960
# 14   3.168
# 15   6.432
# 16   0.928
# 17  23.968
# 18  30.016
# 23  21.088
# Number of features found in /mnt/d/Aqoustics/UMAP/ind_D1_20220829_120600.WAV: 19
# Finished processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_120600.WAV
# Processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_120800.WAV
#   labelID    label  min_y  min_x  max_y  max_x    min_f   min_t     max_f  \
# 0       1  unknown      4   1754     99   1759   62.500  56.160  1546.875
# 1       2  unknown      5    274     66    279   78.125   8.800  1031.250
# 2       3  unknown      5    520    117    524   78.125  16.672  1828.125
# 3       4  unknown      5   1145     43   1150   78.125  36.672   671.875
# 5      12  unknown     49   1145     98   1149  765.625  36.672  1531.250
#
#     max_t
# 0  56.320
# 1   8.960
# 2  16.800
# 3  36.832
# 5  36.800
# Number of features found in /mnt/d/Aqoustics/UMAP/ind_D1_20220829_120800.WAV: 5
# Finished processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_120800.WAV
# Processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_121000.WAV
#   labelID    label  min_y  min_x  max_y  max_x    min_f   min_t     max_f  \
# 0       1  unknown      5    318     42    323   78.125  10.208   656.250
# 2       4  unknown     26   1385     37   1389  406.250  44.352   578.125
# 3      14  unknown     48    318     96    323  750.000  10.208  1500.000
#
#     max_t
# 0  10.368
# 2  44.480
# 3  10.368
# Number of features found in /mnt/d/Aqoustics/UMAP/ind_D1_20220829_121000.WAV: 3
# Finished processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_121000.WAV
# Processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_121200.WAV
#   labelID    label  min_y  min_x  max_y  max_x    min_f   min_t     max_f  \
# 0       1  unknown     25    102     37    108  390.625   3.296   578.125
# 1       2  unknown     26    223     36    230  406.250   7.168   562.500
# 2       4  unknown     26    481     36    485  406.250  15.424   562.500
# 3      20  unknown     58   1142     69   1146  906.250  36.576  1078.125
#
#     max_t
# 0   3.488
# 1   7.392
# 2  15.552
# 3  36.704
# Number of features found in /mnt/d/Aqoustics/UMAP/ind_D1_20220829_121200.WAV: 4
# Finished processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_121200.WAV
# Processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_121400.WAV
#   labelID    label  min_y  min_x  max_y  max_x     min_f   min_t     max_f  \
# 0       1  unknown      6   1140    120   1147    93.750  36.512  1875.000
# 2       3  unknown      9    991     35    995   140.625  31.744   546.875
# 3       4  unknown     20    158     68    166   312.500   5.088  1062.500
# 4       6  unknown     25   1327     36   1331   390.625  42.496   562.500
# 5      23  unknown     57   1189     68   1193   890.625  38.080  1062.500
# 6      25  unknown     58    916     70    920   906.250  29.344  1093.750
# 7      26  unknown    112    916    123    920  1750.000  29.344  1921.875
#
#     max_t
# 0  36.736
# 2  31.872
# 3   5.344
# 4  42.624
# 5  38.208
# 6  29.472
# 7  29.472
# Number of features found in /mnt/d/Aqoustics/UMAP/ind_D1_20220829_121400.WAV: 7
# Finished processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_121400.WAV
# Processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_121600.WAV
#   labelID    label  min_y  min_x  max_y  max_x    min_f   min_t    max_f  \
# 2       4  unknown     19   1757     34   1761  296.875  56.256  531.250
# 3       6  unknown     24    461     38    465  375.000  14.784  593.750
# 4       9  unknown     25     57     36     61  390.625   1.856  562.500
# 5      10  unknown     25   1306     37   1310  390.625  41.824  578.125
#
#     max_t
# 2  56.384
# 3  14.912
# 4   1.984
# 5  41.952
# Number of features found in /mnt/d/Aqoustics/UMAP/ind_D1_20220829_121600.WAV: 4
# Finished processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_121600.WAV
# Processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_121800.WAV
#    labelID    label  min_y  min_x  max_y  max_x     min_f   min_t     max_f  \
# 0        1  unknown      4   1459     98   1465    62.500  46.720  1531.250
# 2        3  unknown      6    764     35    770    93.750  24.480   546.875
# 3        4  unknown     11   1364     35   1372   171.875  43.680   546.875
# 4        5  unknown     12    229     37    233   187.500   7.360   578.125
# 5        6  unknown     23    783     47    789   359.375  25.088   734.375
# 6        8  unknown     24    354     37    358   375.000  11.360   578.125
# 7        9  unknown     24    665     37    669   375.000  21.312   578.125
# 8       10  unknown     24    806     35    810   375.000  25.824   546.875
# 9       35  unknown     53    783     92    789   828.125  25.088  1437.500
# 10      36  unknown     56    342     71    346   875.000  10.976  1109.375
# 11      37  unknown     56   1441     71   1445   875.000  46.144  1109.375
# 13      39  unknown    110    342    121    346  1718.750  10.976  1890.625
# 14      41  unknown    111   1731    123   1735  1734.375  55.424  1921.875
#
#      max_t
# 0   46.912
# 2   24.672
# 3   43.936
# 4    7.488
# 5   25.280
# 6   11.488
# 7   21.440
# 8   25.952
# 9   25.280
# 10  11.104
# 11  46.272
# 13  11.104
# 14  55.552
# Number of features found in /mnt/d/Aqoustics/UMAP/ind_D1_20220829_121800.WAV: 13
# Finished processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_121800.WAV
# Processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_122000.WAV
#   labelID    label  min_y  min_x  max_y  max_x    min_f   min_t     max_f  \
# 0       1  unknown      3     30     89     36   46.875   0.992  1390.625
# 1       2  unknown      4    695     95    701   62.500  22.272  1484.375
# 2       5  unknown     27     99     37    103  421.875   3.200   578.125
# 3      10  unknown     27   1377     49   1383  421.875  44.096   765.625
# 4      25  unknown     54   1377     77   1383  843.750  44.096  1203.125
# 5      26  unknown     56     99     71    103  875.000   3.200  1109.375
# 6      28  unknown     58    979     70    983  906.250  31.360  1093.750
#
#     max_t
# 0   1.184
# 1  22.464
# 2   3.328
# 3  44.288
# 4  44.288
# 5   3.328
# 6  31.488
# Number of features found in /mnt/d/Aqoustics/UMAP/ind_D1_20220829_122000.WAV: 7
# Finished processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_122000.WAV
# Processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_122200.WAV
#   labelID    label  min_y  min_x  max_y  max_x    min_f   min_t    max_f  \
# 2       5  unknown     22    739     35    743  343.750  23.680  546.875
# 3       7  unknown     23   1125     48   1129  359.375  36.032  750.000
#
#     max_t
# 2  23.808
# 3  36.160
# Number of features found in /mnt/d/Aqoustics/UMAP/ind_D1_20220829_122200.WAV: 2
# Finished processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_122200.WAV
# Processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_122400.WAV
#   labelID    label  min_y  min_x  max_y  max_x    min_f   min_t    max_f  \
# 1       2  unknown      6   1643     96   1647   93.750  52.608  1500.00
# 3       5  unknown     22   1721     34   1725  343.750  55.104   531.25
# 4      16  unknown     57   1721     68   1725  890.625  55.104  1062.50
#
#     max_t
# 1  52.736
# 3  55.232
# 4  55.232
# Number of features found in /mnt/d/Aqoustics/UMAP/ind_D1_20220829_122400.WAV: 3
# Finished processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_122400.WAV
# Processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_122600.WAV
#   labelID    label  min_y  min_x  max_y  max_x    min_f   min_t     max_f  \
# 1       2  unknown      5     64     44     69   78.125   2.080   687.500
# 2       3  unknown     14   1742     33   1746  218.750  55.776   515.625
# 3      13  unknown     51     65     99     69  796.875   2.112  1546.875
#
#     max_t
# 1   2.240
# 2  55.904
# 3   2.240
# Number of features found in /mnt/d/Aqoustics/UMAP/ind_D1_20220829_122600.WAV: 3
# Finished processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_122600.WAV
# Processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_122800.WAV
#   labelID    label  min_y  min_x  max_y  max_x     min_f   min_t     max_f  \
# 0       1  unknown     23    849     38    863   359.375  27.200   593.750
# 1       2  unknown     23   1514     34   1520   359.375  48.480   531.250
# 2       3  unknown     26    568     37    574   406.250  18.208   578.125
# 4      18  unknown    115    498    126    504  1796.875  15.968  1968.750
# 5      20  unknown    117    799    127    805  1828.125  25.600  1984.375
#
#     max_t
# 0  27.648
# 1  48.672
# 2  18.400
# 4  16.160
# 5  25.792
# Number of features found in /mnt/d/Aqoustics/UMAP/ind_D1_20220829_122800.WAV: 5
# Finished processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_122800.WAV
# Processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_123000.WAV
#   labelID    label  min_y  min_x  max_y  max_x   min_f   min_t     max_f  \
# 0       1  unknown      5    126     77    130  78.125   4.064  1203.125
# 1       2  unknown      5    201     75    205  78.125   6.464  1171.875
# 2       3  unknown      5   1250     73   1254  78.125  40.032  1140.625
# 3       4  unknown      5   1264     72   1268  78.125  40.480  1125.000
#
#     max_t
# 0   4.192
# 1   6.592
# 2  40.160
# 3  40.608
# Number of features found in /mnt/d/Aqoustics/UMAP/ind_D1_20220829_123000.WAV: 4
# Finished processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_123000.WAV
# Processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_123200.WAV
#   labelID    label  min_y  min_x  max_y  max_x    min_f   min_t     max_f  \
# 2       4  unknown     23   1439     35   1444  359.375  46.080   546.875
# 3       5  unknown     24    831     38    837  375.000  26.624   593.750
# 4       6  unknown     24   1474     37   1480  375.000  47.200   578.125
# 5      26  unknown     59   1422     70   1426  921.875  45.536  1093.750
#
#     max_t
# 2  46.240
# 3  26.816
# 4  47.392
# 5  45.664
# Number of features found in /mnt/d/Aqoustics/UMAP/ind_D1_20220829_123200.WAV: 4
# Finished processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_123200.WAV
# Processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_123400.WAV
#    labelID    label  min_y  min_x  max_y  max_x     min_f   min_t     max_f  \
# 0        1  unknown      5   1506     85   1512    78.125  48.224  1328.125
# 1        2  unknown      9   1640     36   1646   140.625  52.512   562.500
# 2        3  unknown     19    114     36    124   296.875   3.680   562.500
# 3        5  unknown     22   1728     49   1734   343.750  55.328   765.625
# 4        6  unknown     23     96     35    111   359.375   3.104   546.875
# 5        7  unknown     23    717     49    723   359.375  22.976   765.625
# 6       11  unknown     25    518     36    525   390.625  16.608   562.500
# 7       30  unknown     55    518     67    524   859.375  16.608  1046.875
# 8       31  unknown     56    718     70    722   875.000  23.008  1093.750
# 15      43  unknown    117    482    128    486  1828.125  15.456  2000.000
#
#      max_t
# 0   48.416
# 1   52.704
# 2    4.000
# 3   55.520
# 4    3.584
# 5   23.168
# 6   16.832
# 7   16.800
# 8   23.136
# 15  15.584
# Number of features found in /mnt/d/Aqoustics/UMAP/ind_D1_20220829_123400.WAV: 10
# Finished processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_123400.WAV
# Processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_123600.WAV
#   labelID    label  min_y  min_x  max_y  max_x    min_f   min_t    max_f  \
# 0       4  unknown     21    369     34    374  328.125  11.840  531.250
# 1       5  unknown     22   1331     47   1338  343.750  42.624  734.375
# 2       6  unknown     25      6     36     13  390.625   0.224  562.500
# 3       7  unknown     26   1476     36   1482  406.250  47.264  562.500
# 4       8  unknown     27    326     34    338  421.875  10.464  531.250
#
#     max_t
# 0  12.000
# 1  42.848
# 2   0.448
# 3  47.456
# 4  10.848
# Number of features found in /mnt/d/Aqoustics/UMAP/ind_D1_20220829_123600.WAV: 5
# Finished processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_123600.WAV
# Processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_123800.WAV
#    labelID    label  min_y  min_x  max_y  max_x     min_f   min_t     max_f  \
# 0        4  unknown     21   1207     32   1211   328.125  38.656   500.000
# 1        5  unknown     23    630     37    635   359.375  20.192   578.125
# 2        6  unknown     24    647     35    652   375.000  20.736   546.875
# 3        7  unknown     24   1328     37   1334   375.000  42.528   578.125
# 4        9  unknown     26    266     35    274   406.250   8.544   546.875
# 5       13  unknown     27    674     38    680   421.875  21.600   593.750
# 6       14  unknown     27    908     36    914   421.875  29.088   562.500
# 7       15  unknown     27   1081     37   1087   421.875  34.624   578.125
# 8       17  unknown     27   1238     36   1243   421.875  39.648   562.500
# 9       20  unknown     27   1723     37   1731   421.875  55.168   578.125
# 10      43  unknown     60    675     72    679   937.500  21.632  1125.000
# 13      57  unknown    116   1246    128   1250  1812.500  39.904  2000.000
#
#      max_t
# 0   38.784
# 1   20.352
# 2   20.896
# 3   42.720
# 4    8.800
# 5   21.792
# 6   29.280
# 7   34.816
# 8   39.808
# 9   55.424
# 10  21.760
# 13  40.032
# Number of features found in /mnt/d/Aqoustics/UMAP/ind_D1_20220829_123800.WAV: 12
# Finished processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_123800.WAV
# Processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_124000.WAV
#   labelID    label  min_y  min_x  max_y  max_x    min_f   min_t     max_f  \
# 1       4  unknown     25    491     37    505  390.625  15.744   578.125
# 2       5  unknown     26   1443     36   1447  406.250  46.208   562.500
# 3       8  unknown     27   1403     34   1409  421.875  44.928   531.250
# 4      20  unknown     60   1564     72   1568  937.500  50.080  1125.000
#
#     max_t
# 1  16.192
# 2  46.336
# 3  45.120
# 4  50.208
# Number of features found in /mnt/d/Aqoustics/UMAP/ind_D1_20220829_124000.WAV: 4
# Finished processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_124000.WAV
# Processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_124200.WAV
#   labelID    label  min_y  min_x  max_y  max_x    min_f   min_t    max_f  \
# 0       2  unknown     11   1768     33   1772  171.875  56.608  515.625
# 1       3  unknown     13    400     34    406  203.125  12.832  531.250
# 2       5  unknown     16   1444     32   1448  250.000  46.240  500.000
# 3       8  unknown     26    845     37    851  406.250  27.072  578.125
#
#     max_t
# 0  56.736
# 1  13.024
# 2  46.368
# 3  27.264
# Number of features found in /mnt/d/Aqoustics/UMAP/ind_D1_20220829_124200.WAV: 4
# Finished processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_124200.WAV
# Processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_124400.WAV
#   labelID    label  min_y  min_x  max_y  max_x    min_f   min_t     max_f  \
# 0       5  unknown     18   1233     32   1237  281.250  39.488   500.000
# 1       7  unknown     19    659     38    665  296.875  21.120   593.750
# 2       8  unknown     22    710     38    716  343.750  22.752   593.750
# 3       9  unknown     23    277     35    283  359.375   8.896   546.875
# 4      10  unknown     25    309     36    315  390.625   9.920   562.500
# 5      11  unknown     26    962     36    968  406.250  30.816   562.500
# 6      15  unknown     27    700     33    708  421.875  22.432   515.625
# 7      29  unknown     55    488     71    494  859.375  15.648  1109.375
#
#     max_t
# 0  39.616
# 1  21.312
# 2  22.944
# 3   9.088
# 4  10.112
# 5  31.008
# 6  22.688
# 7  15.840
# Number of features found in /mnt/d/Aqoustics/UMAP/ind_D1_20220829_124400.WAV: 8
# Finished processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_124400.WAV
# Processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_124600.WAV
#   labelID    label  min_y  min_x  max_y  max_x     min_f   min_t     max_f  \
# 0       1  unknown      4   1465    125   1472    62.500  46.912  1953.125
# 1       2  unknown      7    734     65    739   109.375  23.520  1015.625
# 2       4  unknown     23    500     34    510   359.375  16.032   531.250
# 3       5  unknown     25   1328     35   1332   390.625  42.528   546.875
# 4      15  unknown     28    975     35    982   437.500  31.232   546.875
# 5      32  unknown     59   1750     72   1754   921.875  56.032  1125.000
# 6      33  unknown     70    734    118    738  1093.750  23.520  1843.750
# 7      34  unknown    115   1750    126   1754  1796.875  56.032  1968.750
#
#     max_t
# 0  47.136
# 1  23.680
# 2  16.352
# 3  42.656
# 4  31.456
# 5  56.160
# 6  23.648
# 7  56.160
# Number of features found in /mnt/d/Aqoustics/UMAP/ind_D1_20220829_124600.WAV: 8
# Finished processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_124600.WAV
# Processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_124800.WAV
#   labelID    label  min_y  min_x  max_y  max_x    min_f   min_t     max_f  \
# 0       3  unknown     18    227     33    233  281.250   7.296   515.625
# 1       4  unknown     18    384     37    390  281.250  12.320   578.125
# 2       5  unknown     22    208     49    214  343.750   6.688   765.625
# 3       6  unknown     23   1026     33   1034  359.375  32.864   515.625
# 4       7  unknown     24    317     34    322  375.000  10.176   531.250
# 5       8  unknown     24    963     38    968  375.000  30.848   593.750
# 6       9  unknown     25   1100     39   1107  390.625  35.232   609.375
# 7      10  unknown     26    853     34    864  406.250  27.328   531.250
# 8      24  unknown     53    209     77    213  828.125   6.720  1203.125
#
#     max_t
# 0   7.488
# 1  12.512
# 2   6.880
# 3  33.120
# 4  10.336
# 5  31.008
# 6  35.456
# 7  27.680
# 8   6.848
# Number of features found in /mnt/d/Aqoustics/UMAP/ind_D1_20220829_124800.WAV: 9
# Finished processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_124800.WAV
# Processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_125000.WAV
#   labelID    label  min_y  min_x  max_y  max_x     min_f   min_t     max_f  \
# 0       1  unknown     25   1187     35   1193   390.625  38.016   546.875
# 1      16  unknown     59    299     69    303   921.875   9.600  1078.125
# 3      21  unknown    115    262    126    266  1796.875   8.416  1968.750
#
#     max_t
# 0  38.208
# 1   9.728
# 3   8.544
# Number of features found in /mnt/d/Aqoustics/UMAP/ind_D1_20220829_125000.WAV: 3
# Finished processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_125000.WAV
# Processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_125200.WAV
#   labelID    label  min_y  min_x  max_y  max_x    min_f   min_t     max_f  \
# 1       3  unknown     14    106     34    115  218.750   3.424   531.250
# 2       4  unknown     15    423     34    430  234.375  13.568   531.250
# 3       5  unknown     16    932     33    940  250.000  29.856   515.625
# 4       6  unknown     16   1582     32   1589  250.000  50.656   500.000
# 5       7  unknown     22     61     36     65  343.750   1.984   562.500
# 6       8  unknown     25   1650     35   1656  390.625  52.832   546.875
# 7      26  unknown     58   1544     72   1548  906.250  49.440  1125.000
#
#     max_t
# 1   3.712
# 2  13.792
# 3  30.112
# 4  50.880
# 5   2.112
# 6  53.024
# 7  49.568
# Number of features found in /mnt/d/Aqoustics/UMAP/ind_D1_20220829_125200.WAV: 7
# Finished processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_125200.WAV
# Processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_125400.WAV
#   labelID    label  min_y  min_x  max_y  max_x     min_f   min_t     max_f  \
# 0       1  unknown     24    400     37    406   375.000  12.832   578.125
# 2      24  unknown    115    693    126    699  1796.875  22.208  1968.750
#
#     max_t
# 0  13.024
# 2  22.400
# Number of features found in /mnt/d/Aqoustics/UMAP/ind_D1_20220829_125400.WAV: 2
# Finished processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_125400.WAV
# Processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_125600.WAV
#   labelID    label  min_y  min_x  max_y  max_x    min_f   min_t    max_f  \
# 0       1  unknown     11    237     34    243  171.875   7.616  531.250
# 1       3  unknown     22    971     37    977  343.750  31.104  578.125
# 2       4  unknown     23    323     38    329  359.375  10.368  593.750
# 3       5  unknown     23    898     37    904  359.375  28.768  578.125
# 4       8  unknown     26    539     36    545  406.250  17.280  562.500
# 5      15  unknown     28   1278     38   1284  437.500  40.928  593.750
#
#     max_t
# 0   7.808
# 1  31.296
# 2  10.560
# 3  28.960
# 4  17.472
# 5  41.120
# Number of features found in /mnt/d/Aqoustics/UMAP/ind_D1_20220829_125600.WAV: 6
# Finished processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_125600.WAV
# Processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_125800.WAV
#   labelID    label  min_y  min_x  max_y  max_x     min_f   min_t     max_f  \
# 1       3  unknown     21    859     77    865   328.125  27.520  1203.125
# 2       5  unknown     23    532     38    538   359.375  17.056   593.750
# 3       6  unknown     27    138     35    146   421.875   4.448   546.875
# 6      35  unknown    115    209    127    214  1796.875   6.720  1984.375
#
#     max_t
# 1  27.712
# 2  17.248
# 3   4.704
# 6   6.880
# Number of features found in /mnt/d/Aqoustics/UMAP/ind_D1_20220829_125800.WAV: 4
# Finished processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_125800.WAV
# Processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_130000.WAV
#   labelID    label  min_y  min_x  max_y  max_x     min_f   min_t     max_f  \
# 0       1  unknown      4    980    103    986    62.500  31.392  1609.375
# 2       3  unknown      7     81    120     85   109.375   2.624  1875.000
# 4      12  unknown     24    606     55    611   375.000  19.424   859.375
# 5      17  unknown     58    606     75    611   906.250  19.424  1171.875
# 6      18  unknown    114    606    128    611  1781.250  19.424  2000.000
#
#     max_t
# 0  31.584
# 2   2.752
# 4  19.584
# 5  19.584
# 6  19.584
# Number of features found in /mnt/d/Aqoustics/UMAP/ind_D1_20220829_130000.WAV: 5
# Finished processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_130000.WAV
# Processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_130200.WAV
#   labelID    label  min_y  min_x  max_y  max_x     min_f   min_t     max_f  \
# 0       1  unknown      5    454     47    459    78.125  14.560   734.375
# 2       3  unknown      6    429     46    434    93.750  13.760   718.750
# 4       5  unknown      8   1648     68   1652   125.000  52.768  1062.500
# 6      13  unknown     27   1301     59   1305   421.875  41.664   921.875
# 7      24  unknown     61   1302    109   1304   953.125  41.696  1703.125
# 8      26  unknown     71   1649    112   1651  1109.375  52.800  1750.000
#
#     max_t
# 0  14.720
# 2  13.920
# 4  52.896
# 6  41.792
# 7  41.760
# 8  52.864
# Number of features found in /mnt/d/Aqoustics/UMAP/ind_D1_20220829_130200.WAV: 6
# Finished processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_130200.WAV
# Processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_130400.WAV
#   labelID    label  min_y  min_x  max_y  max_x    min_f   min_t     max_f  \
# 0       1  unknown      5    644     64    649   78.125  20.640  1000.000
# 2       3  unknown      7    657     69    662  109.375  21.056  1078.125
# 3       6  unknown     22    628     36    632  343.750  20.128   562.500
# 4       9  unknown     24     52     37     56  375.000   1.696   578.125
# 5      10  unknown     24   1157     36   1167  375.000  37.056   562.500
# 6      11  unknown     25    941     38    945  390.625  30.144   593.750
#
#     max_t
# 0  20.800
# 2  21.216
# 3  20.256
# 4   1.824
# 5  37.376
# 6  30.272
# Number of features found in /mnt/d/Aqoustics/UMAP/ind_D1_20220829_130400.WAV: 6
# Finished processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_130400.WAV
# Processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_130600.WAV
#   labelID    label  min_y  min_x  max_y  max_x     min_f   min_t     max_f  \
# 0       1  unknown      5    628     96    632    78.125  20.128  1500.000
# 1       2  unknown      6   1113     77   1118    93.750  35.648  1203.125
# 2       3  unknown     11   1702     36   1708   171.875  54.496   562.500
# 3       6  unknown     22   1821     37   1826   343.750  58.304   578.125
# 4       7  unknown     23     76     38     80   359.375   2.464   593.750
# 5       9  unknown     26    912     36    917   406.250  29.216   562.500
# 6      22  unknown    104    628    124    632  1625.000  20.128  1937.500
#
#     max_t
# 0  20.256
# 1  35.808
# 2  54.688
# 3  58.464
# 4   2.592
# 5  29.376
# 6  20.256
# Number of features found in /mnt/d/Aqoustics/UMAP/ind_D1_20220829_130600.WAV: 7
# Finished processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_130600.WAV
# Processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_130800.WAV
#   labelID    label  min_y  min_x  max_y  max_x  min_f   min_t   max_f   max_t
# 3       4  unknown      8   1560     34   1566  125.0  49.952  531.25  50.144
# Number of features found in /mnt/d/Aqoustics/UMAP/ind_D1_20220829_130800.WAV: 1
# Finished processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_130800.WAV
# Processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_131000.WAV
#   labelID    label  min_y  min_x  max_y  max_x     min_f   min_t     max_f  \
# 4       5  unknown     13   1063     49   1068   203.125  34.048   765.625
# 5       7  unknown     23   1779     33   1787   359.375  56.960   515.625
# 6      18  unknown     73   1064    103   1067  1140.625  34.080  1609.375
#
#     max_t
# 4  34.208
# 5  57.216
# 6  34.176
# Number of features found in /mnt/d/Aqoustics/UMAP/ind_D1_20220829_131000.WAV: 3
# Finished processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_131000.WAV
# Processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_131200.WAV
#   labelID    label  min_y  min_x  max_y  max_x     min_f   min_t     max_f  \
# 0       1  unknown      5   1150     66   1154    78.125  36.832  1031.250
# 1       2  unknown      5   1198     67   1203    78.125  38.368  1046.875
# 3       4  unknown     25    119     36    123   390.625   3.840   562.500
# 7      25  unknown    113   1184    125   1188  1765.625  37.920  1953.125
#
#     max_t
# 0  36.960
# 1  38.528
# 3   3.968
# 7  38.048
# Number of features found in /mnt/d/Aqoustics/UMAP/ind_D1_20220829_131200.WAV: 4
# Finished processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_131200.WAV
# Processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_131400.WAV
#   labelID    label  min_y  min_x  max_y  max_x     min_f   min_t     max_f  \
# 1       2  unknown      7    598     63    602   109.375  19.168   984.375
# 2       4  unknown     18   1510     36   1516   281.250  48.352   562.500
# 3       5  unknown     19    263     35    270   296.875   8.448   546.875
# 4       6  unknown     23     78     38     83   359.375   2.528   593.750
# 5      21  unknown     57    451     75    455   890.625  14.464  1171.875
# 6      22  unknown     69    598    124    602  1078.125  19.168  1937.500
#
#     max_t
# 1  19.296
# 2  48.544
# 3   8.672
# 4   2.688
# 5  14.592
# 6  19.296
# Number of features found in /mnt/d/Aqoustics/UMAP/ind_D1_20220829_131400.WAV: 6
# Finished processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_131400.WAV
# Processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_131600.WAV
#   labelID    label  min_y  min_x  max_y  max_x     min_f   min_t     max_f  \
# 0       3  unknown     19   1121     38   1127   296.875  35.904   593.750
# 1       5  unknown     22   1777     35   1784   343.750  56.896   546.875
# 2       6  unknown     24    765     44    771   375.000  24.512   687.500
# 3       7  unknown     25    153     38    159   390.625   4.928   593.750
# 4       8  unknown     26   1015     35   1021   406.250  32.512   546.875
# 6      29  unknown    115    153    126    159  1796.875   4.928  1968.750
#
#     max_t
# 0  36.096
# 1  57.120
# 2  24.704
# 3   5.120
# 4  32.704
# 6   5.120
# Number of features found in /mnt/d/Aqoustics/UMAP/ind_D1_20220829_131600.WAV: 6
# Finished processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_131600.WAV
# Processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_131800.WAV
#   labelID    label  min_y  min_x  max_y  max_x    min_f   min_t     max_f  \
# 0       1  unknown      5   1398     92   1402   78.125  44.768  1437.500
# 6      21  unknown     58    502     71    506  906.250  16.096  1109.375
#
#     max_t
# 0  44.896
# 6  16.224
# Number of features found in /mnt/d/Aqoustics/UMAP/ind_D1_20220829_131800.WAV: 2
# Finished processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_131800.WAV
# Processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_132000.WAV
#   labelID    label  min_y  min_x  max_y  max_x    min_f   min_t     max_f  \
# 2       3  unknown      8   1139     35   1156  125.000  36.480   546.875
# 3       7  unknown     23    982     36    988  359.375  31.456   562.500
# 4       8  unknown     23   1446     38   1450  359.375  46.304   593.750
# 5       9  unknown     23   1821     37   1825  359.375  58.304   578.125
# 6      12  unknown     26    310     38    314  406.250   9.952   593.750
# 7      13  unknown     27    852     35    861  421.875  27.296   546.875
# 8      26  unknown     60    906     71    910  937.500  29.024  1109.375
#
#     max_t
# 2  37.024
# 3  31.648
# 4  46.432
# 5  58.432
# 6  10.080
# 7  27.584
# 8  29.152
# Number of features found in /mnt/d/Aqoustics/UMAP/ind_D1_20220829_132000.WAV: 7
# Finished processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_132000.WAV
# Processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_132200.WAV
#    labelID    label  min_y  min_x  max_y  max_x     min_f   min_t     max_f  \
# 0        1  unknown      6   1779     33   1785    93.750  56.960   515.625
# 1        2  unknown      8    606     36    613   125.000  19.424   562.500
# 2        5  unknown     21   1795     40   1802   328.125  57.472   625.000
# 3        6  unknown     22   1187     37   1193   343.750  38.016   578.125
# 4        7  unknown     23    448     35    455   359.375  14.368   546.875
# 5        8  unknown     24   1001     35   1007   375.000  32.064   546.875
# 6       11  unknown     26   1602     35   1608   406.250  51.296   546.875
# 7       12  unknown     27    367     37    373   421.875  11.776   578.125
# 8       14  unknown     27    976     36    983   421.875  31.264   562.500
# 9       15  unknown     27   1148     37   1154   421.875  36.768   578.125
# 10      26  unknown    116   1735    126   1739  1812.500  55.552  1968.750
#
#      max_t
# 0   57.152
# 1   19.648
# 2   57.696
# 3   38.208
# 4   14.592
# 5   32.256
# 6   51.488
# 7   11.968
# 8   31.488
# 9   36.960
# 10  55.680
# Number of features found in /mnt/d/Aqoustics/UMAP/ind_D1_20220829_132200.WAV: 11
# Finished processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_132200.WAV
# Processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_132400.WAV
#   labelID    label  min_y  min_x  max_y  max_x    min_f   min_t     max_f  \
# 0       1  unknown      4   1435     78   1441   62.500  45.952  1218.750
# 1       2  unknown      7    913     35    919  109.375  29.248   546.875
# 2       3  unknown     20   1061     37   1068  312.500  33.984   578.125
# 3       4  unknown     22    512     33    516  343.750  16.416   515.625
# 4       8  unknown     26    573     37    579  406.250  18.368   578.125
#
#     max_t
# 0  46.144
# 1  29.440
# 2  34.208
# 3  16.544
# 4  18.560
# Number of features found in /mnt/d/Aqoustics/UMAP/ind_D1_20220829_132400.WAV: 5
# Finished processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_132400.WAV
# Processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_132600.WAV
#   labelID    label  min_y  min_x  max_y  max_x     min_f   min_t     max_f  \
# 0       1  unknown      8    564     35    568   125.000  18.080   546.875
# 1       2  unknown      9    231     36    237   140.625   7.424   562.500
# 2       4  unknown     10    651     35    656   156.250  20.864   546.875
# 3       5  unknown     12    590     33    595   187.500  18.912   515.625
# 4       7  unknown     23    688     35    695   359.375  22.048   546.875
# 5      20  unknown    115    259    127    264  1796.875   8.320  1984.375
#
#     max_t
# 0  18.208
# 1   7.616
# 2  21.024
# 3  19.072
# 4  22.272
# 5   8.480
# Number of features found in /mnt/d/Aqoustics/UMAP/ind_D1_20220829_132600.WAV: 6
# Finished processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_132600.WAV
# Processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_132800.WAV
#   labelID    label  min_y  min_x  max_y  max_x    min_f   min_t    max_f  \
# 1       4  unknown     10   1564     36   1569  156.250  50.080  562.500
# 2       6  unknown     11    402     23    406  171.875  12.896  359.375
# 3       8  unknown     19   1237     36   1243  296.875  39.616  562.500
# 4       9  unknown     20   1029     32   1034  312.500  32.960  500.000
# 5      10  unknown     21   1066     37   1072  328.125  34.144  578.125
# 6      11  unknown     23   1086     35   1092  359.375  34.784  546.875
# 7      13  unknown     27     62     35     71  421.875   2.016  546.875
#
#     max_t
# 1  50.240
# 2  13.024
# 3  39.808
# 4  33.120
# 5  34.336
# 6  34.976
# 7   2.304
# Number of features found in /mnt/d/Aqoustics/UMAP/ind_D1_20220829_132800.WAV: 7
# Finished processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_132800.WAV
# Processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_133000.WAV
#   labelID    label  min_y  min_x  max_y  max_x    min_f   min_t     max_f  \
# 0       1  unknown      5    436     80    441   78.125  13.984  1250.000
# 1       2  unknown      6    420     33    425   93.750  13.472   515.625
# 3       4  unknown      8    258     34    262  125.000   8.288   531.250
# 4       8  unknown     24   1752     38   1756  375.000  56.096   593.750
# 5       9  unknown     27   1510     36   1515  421.875  48.352   562.500
# 6      21  unknown     42    420     92    425  656.250  13.472  1437.500
#
#     max_t
# 0  14.144
# 1  13.632
# 3   8.416
# 4  56.224
# 5  48.512
# 6  13.632
# Number of features found in /mnt/d/Aqoustics/UMAP/ind_D1_20220829_133000.WAV: 6
# Finished processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_133000.WAV
# Processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_133200.WAV
#   labelID    label  min_y  min_x  max_y  max_x    min_f   min_t     max_f  \
# 0       1  unknown      4    467     80    471   62.500  14.976  1250.000
# 1       7  unknown     13   1077     35   1081  203.125  34.496   546.875
# 2       8  unknown     15    420     37    425  234.375  13.472   578.125
# 3      11  unknown     22   1049     36   1055  343.750  33.600   562.500
# 4      12  unknown     22   1256     37   1263  343.750  40.224   578.125
# 5      13  unknown     22   1451     35   1460  343.750  46.464   546.875
# 6      15  unknown     24   1205     35   1209  375.000  38.592   546.875
# 7      16  unknown     27   1399     37   1404  421.875  44.800   578.125
#
#     max_t
# 0  15.104
# 1  34.624
# 2  13.632
# 3  33.792
# 4  40.448
# 5  46.752
# 6  38.720
# 7  44.960
# Number of features found in /mnt/d/Aqoustics/UMAP/ind_D1_20220829_133200.WAV: 8
# Finished processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_133200.WAV
# Processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_133400.WAV
#   labelID    label  min_y  min_x  max_y  max_x    min_f   min_t     max_f  \
# 2       3  unknown      6   1745     47   1750   93.750  55.872   734.375
# 4       5  unknown     11    653     36    657  171.875  20.928   562.500
# 5       6  unknown     22    470     37    474  343.750  15.072   578.125
# 6      22  unknown     49   1745     69   1750  765.625  55.872  1078.125
# 7      23  unknown     58    297     75    301  906.250   9.536  1171.875
#
#     max_t
# 2  56.032
# 4  21.056
# 5  15.200
# 6  56.032
# 7   9.664
# Number of features found in /mnt/d/Aqoustics/UMAP/ind_D1_20220829_133400.WAV: 5
# Finished processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_133400.WAV
# Processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_133600.WAV
#   labelID    label  min_y  min_x  max_y  max_x    min_f   min_t     max_f  \
# 1       2  unknown      6    826    120    832   93.750  26.464  1875.000
# 2       3  unknown      9    705     36    724  140.625  22.592   562.500
# 3       4  unknown     18   1779     35   1786  281.250  56.960   546.875
# 4      20  unknown     57    430     73    434  890.625  13.792  1140.625
#
#     max_t
# 1  26.656
# 2  23.200
# 3  57.184
# 4  13.920
# Number of features found in /mnt/d/Aqoustics/UMAP/ind_D1_20220829_133600.WAV: 4
# Finished processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_133600.WAV
# Processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_133800.WAV
#   labelID    label  min_y  min_x  max_y  max_x    min_f   min_t     max_f  \
# 1       3  unknown     23    117     36    121  359.375   3.776   562.500
# 2       4  unknown     26    476     35    485  406.250  15.264   546.875
# 3      19  unknown     53    117     70    121  828.125   3.776  1093.750
# 4      21  unknown     58   1491     73   1495  906.250  47.744  1140.625
#
#     max_t
# 1   3.904
# 2  15.552
# 3   3.904
# 4  47.872
# Number of features found in /mnt/d/Aqoustics/UMAP/ind_D1_20220829_133800.WAV: 4
# Finished processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_133800.WAV
# Processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_134000.WAV
#   labelID    label  min_y  min_x  max_y  max_x    min_f   min_t  max_f   max_t
# 0      10  unknown     27   1001     36   1007  421.875  32.064  562.5  32.256
# Number of features found in /mnt/d/Aqoustics/UMAP/ind_D1_20220829_134000.WAV: 1
# Finished processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_134000.WAV
# Processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_134200.WAV
#   labelID    label  min_y  min_x  max_y  max_x     min_f   min_t     max_f  \
# 0       1  unknown     23   1543     36   1549   359.375  49.408   562.500
# 1       3  unknown     24   1560     35   1566   375.000  49.952   546.875
# 2       6  unknown     25    440     35    446   390.625  14.112   546.875
# 3       9  unknown     26   1658     38   1664   406.250  53.088   593.750
# 4      11  unknown     27    798     36    804   421.875  25.568   562.500
# 5      12  unknown     27    913     36    924   421.875  29.248   562.500
# 6      13  unknown     27   1113     37   1119   421.875  35.648   578.125
# 7      28  unknown     59    252     71    256   921.875   8.096  1109.375
# 8      30  unknown     60   1113     76   1119   937.500  35.648  1187.500
# 9      31  unknown    112   1659    124   1663  1750.000  53.120  1937.500
#
#     max_t
# 0  49.600
# 1  50.144
# 2  14.304
# 3  53.280
# 4  25.760
# 5  29.600
# 6  35.840
# 7   8.224
# 8  35.840
# 9  53.248
# Number of features found in /mnt/d/Aqoustics/UMAP/ind_D1_20220829_134200.WAV: 10
# Finished processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_134200.WAV
# Processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_134400.WAV
#   labelID    label  min_y  min_x  max_y  max_x   min_f   min_t   max_f   max_t
# 5       6  unknown     22   1191     34   1202  343.75  38.144  531.25  38.496
# 6       7  unknown     24    961     46    965  375.00  30.784  718.75  30.912
# Number of features found in /mnt/d/Aqoustics/UMAP/ind_D1_20220829_134400.WAV: 2
# Finished processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_134400.WAV
# Processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_134600.WAV
#   labelID    label  min_y  min_x  max_y  max_x     min_f   min_t    max_f  \
# 1       4  unknown     19   1258     38   1264   296.875  40.288   593.75
# 2       5  unknown     21    550     36    556   328.125  17.632   562.50
# 3       6  unknown     22   1321     38   1327   343.750  42.304   593.75
# 4       8  unknown     24    128     34    132   375.000   4.128   531.25
# 7      29  unknown    116   1259    126   1263  1812.500  40.320  1968.75
#
#     max_t
# 1  40.480
# 2  17.824
# 3  42.496
# 4   4.256
# 7  40.448
# Number of features found in /mnt/d/Aqoustics/UMAP/ind_D1_20220829_134600.WAV: 5
# Finished processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_134600.WAV
# Processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_134800.WAV
#   labelID    label  min_y  min_x  max_y  max_x     min_f   min_t     max_f  \
# 2       3  unknown     12   1619     36   1623   187.500  51.840   562.500
# 3       5  unknown     19    351     35    356   296.875  11.264   546.875
# 4       8  unknown     20   1364     38   1369   312.500  43.680   593.750
# 5      10  unknown     22   1084     31   1090   343.750  34.720   484.375
# 6      11  unknown     22   1580     36   1584   343.750  50.592   562.500
# 7      12  unknown     23   1510     36   1514   359.375  48.352   562.500
# 8      13  unknown     24   1550     35   1554   375.000  49.632   546.875
# 9      26  unknown    115    539    126    543  1796.875  17.280  1968.750
#
#     max_t
# 2  51.968
# 3  11.424
# 4  43.840
# 5  34.912
# 6  50.720
# 7  48.480
# 8  49.760
# 9  17.408
# Number of features found in /mnt/d/Aqoustics/UMAP/ind_D1_20220829_134800.WAV: 8
# Finished processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_134800.WAV
# Processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_135000.WAV
#   labelID    label  min_y  min_x  max_y  max_x    min_f   min_t     max_f  \
# 0       1  unknown      4   1393     40   1398   62.500  44.608   625.000
# 1       2  unknown      4   1456     48   1461   62.500  46.624   750.000
# 3       4  unknown      9   1796     35   1798  140.625  57.504   546.875
# 5      28  unknown     51   1456    103   1460  796.875  46.624  1609.375
#
#     max_t
# 0  44.768
# 1  46.784
# 3  57.568
# 5  46.752
# Number of features found in /mnt/d/Aqoustics/UMAP/ind_D1_20220829_135000.WAV: 4
# Finished processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_135000.WAV
# Processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_135200.WAV
#   labelID    label  min_y  min_x  max_y  max_x  min_f  min_t     max_f  max_t
# 0       1  unknown      4    102    105    108   62.5  3.296  1640.625  3.488
# Number of features found in /mnt/d/Aqoustics/UMAP/ind_D1_20220829_135200.WAV: 1
# Finished processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_135200.WAV
# Processing file: /mnt/d/Aqoustics/UMAP/ind_D1_20220829_135400.WAV
#   labelID    label  min_y  min_x  max_y  max_x    min_f   min_t     max_f  \
# ...
# 11      15  unknown     20    377     27    385  312.500  12.096  421.875
# 12      18  unknown     22    208     35    213  343.750   6.688  546.875
#
#      max_t
# 2   40.416
# 3   48.672
# 4   49.664
# 5   56.096
# 6   42.848
# 7   17.504
# 8   26.752
# 9   53.792
# 10  35.552
# 11  12.352
# 12   6.848
# Number of features found in /mnt/d/Aqoustics/UMAP/ind_R6_20220916_100600.WAV: 11
# Finished processing file: /mnt/d/Aqoustics/UMAP/ind_R6_20220916_100600.WAV
# Processing file: /mnt/d/Aqoustics/UMAP/ind_R6_20220917_041400.WAV
#   labelID    label  min_y  min_x  max_y  max_x    min_f   min_t     max_f  \
# 0       1  unknown      5    565    109    569   78.125  18.112  1703.125
# 1       2  unknown      5    607     64    611   78.125  19.456  1000.000
# 3       4  unknown     16    394     39    398  250.000  12.640   609.375
#
#     max_t
# 0  18.240
# 1  19.584
# 3  12.768
# Number of features found in /mnt/d/Aqoustics/UMAP/ind_R6_20220917_041400.WAV: 3
# Finished processing file: /mnt/d/Aqoustics/UMAP/ind_R6_20220917_041400.WAV
# Processing file: /mnt/d/Aqoustics/UMAP/ind_R6_20220917_071800.WAV
#   labelID    label  min_y  min_x  max_y  max_x    min_f   min_t    max_f  \
# 0       1  unknown      4    987     15    992   62.500  31.616  234.375
# 1       2  unknown      4   1133     16   1169   62.500  36.288  250.000
# 2       6  unknown      5    614     11    622   78.125  19.680  171.875
# 3       8  unknown      5    660     56    664   78.125  21.152  875.000
# 4      12  unknown      5   1208     33   1219   78.125  38.688  515.625
# 6      24  unknown     17   1858     29   1862  265.625  59.488  453.125
#
#     max_t
# 0  31.776
# 1  37.440
# 2  19.936
# 3  21.280
# 4  39.040
# 6  59.616
# Number of features found in /mnt/d/Aqoustics/UMAP/ind_R6_20220917_071800.WAV: 6
# Finished processing file: /mnt/d/Aqoustics/UMAP/ind_R6_20220917_071800.WAV
# Processing file: /mnt/d/Aqoustics/UMAP/ind_R6_20220917_131200.WAV
#    labelID    label  min_y  min_x  max_y  max_x    min_f   min_t    max_f  \
# 0        1  unknown      3   1779     18   1786   46.875  56.960  281.250
# 1        2  unknown      4   1052     20   1057   62.500  33.696  312.500
# 2        3  unknown      4   1390     16   1396   62.500  44.512  250.000
# 3        9  unknown     10    521     42    529  156.250  16.704  656.250
# 4       17  unknown     14   1264     30   1271  218.750  40.480  468.750
# 5       18  unknown     16   1100     33   1110  250.000  35.232  515.625
# 6       20  unknown     17    966     29    979  265.625  30.944  453.125
# 7       23  unknown     18    785     29    789  281.250  25.152  453.125
# 8       25  unknown     18   1667     36   1673  281.250  53.376  562.500
# 9       29  unknown     19    755     30    762  296.875  24.192  468.750
# 10      30  unknown     19    950     35    956  296.875  30.432  546.875
# 11      31  unknown     19   1243     28   1249  296.875  39.808  437.500
# 12      34  unknown     21    430     36    437  328.125  13.792  562.500
# 13      41  unknown     22   1509     38   1514  343.750  48.320  593.750
# 14      55  unknown     27   1708     41   1714  421.875  54.688  640.625
#
#      max_t
# 0   57.184
# 1   33.856
# 2   44.704
# 3   16.960
# 4   40.704
# 5   35.552
# 6   31.360
# 7   25.280
# 8   53.568
# 9   24.416
# 10  30.624
# 11  40.000
# 12  14.016
# 13  48.480
# 14  54.880
# Number of features found in /mnt/d/Aqoustics/UMAP/ind_R6_20220917_131200.WAV: 15
# Finished processing file: /mnt/d/Aqoustics/UMAP/ind_R6_20220917_131200.WAV
# Processing file: /mnt/d/Aqoustics/UMAP/ind_R6_20220918_111000.WAV
#   labelID    label  min_y  min_x  max_y  max_x    min_f   min_t    max_f  \
# 0       3  unknown      6    971     36    978   93.750  31.104  562.500
# 1       4  unknown      6   1158     30   1168   93.750  37.088  468.750
# 2       5  unknown      6   1300     32   1307   93.750  41.632  500.000
# 5      24  unknown     17   1667     35   1672  265.625  53.376  546.875
# 6      27  unknown     20    608     36    613  312.500  19.488  562.500
# 7      29  unknown     21    554     35    561  328.125  17.760  546.875
# 8      30  unknown     22    184     34    189  343.750   5.920  531.250
#
#     max_t
# 0  31.328
# 1  37.408
# 2  41.856
# 5  53.536
# 6  19.648
# 7  17.984
# 8   6.080
# Number of features found in /mnt/d/Aqoustics/UMAP/ind_R6_20220918_111000.WAV: 7
# Finished processing file: /mnt/d/Aqoustics/UMAP/ind_R6_20220918_111000.WAV
# Processing file: /mnt/d/Aqoustics/UMAP/ind_R6_20220918_154800.WAV
#   labelID    label  min_y  min_x  max_y  max_x    min_f   min_t     max_f  \
# 0       1  unknown      4     65     85     74   62.500   2.112  1328.125
# 1       2  unknown      4   1005     15   1012   62.500  32.192   234.375
# 2       3  unknown      5    943     32    949   78.125  30.208   500.000
# 3       4  unknown      5    957     30    963   78.125  30.656   468.750
# 4       5  unknown      5    982     16    988   78.125  31.456   250.000
# 5       6  unknown      6   1190     35   1198   93.750  38.112   546.875
# 6      14  unknown     17   1743     34   1749  265.625  55.808   531.250
# 7      16  unknown     19   1006     33   1011  296.875  32.224   515.625
#
#     max_t
# 0   2.400
# 1  32.416
# 2  30.400
# 3  30.848
# 4  31.648
# 5  38.368
# 6  56.000
# 7  32.384
# Number of features found in /mnt/d/Aqoustics/UMAP/ind_R6_20220918_154800.WAV: 8
# Finished processing file: /mnt/d/Aqoustics/UMAP/ind_R6_20220918_154800.WAV
# Processing file: /mnt/d/Aqoustics/UMAP/ind_R6_20220918_163000.WAV
#   labelID    label  min_y  min_x  max_y  max_x    min_f   min_t    max_f  \
# 0       1  unknown      4    932     16    940   62.500  29.856  250.000
# 1       4  unknown     12   1513     31   1519  187.500  48.448  484.375
# 2       5  unknown     14    200     30    206  218.750   6.432  468.750
# 3      11  unknown     20   1247     33   1253  312.500  39.936  515.625
# 4      14  unknown     21    934     31    939  328.125  29.920  484.375
#
#     max_t
# 0  30.112
# 1  48.640
# 2   6.624
# 3  40.128
# 4  30.080
# Number of features found in /mnt/d/Aqoustics/UMAP/ind_R6_20220918_163000.WAV: 5
# Finished processing file: /mnt/d/Aqoustics/UMAP/ind_R6_20220918_163000.WAV
# Processing file: /mnt/d/Aqoustics/UMAP/ind_R6_20220919_074200.WAV
#   labelID    label  min_y  min_x  max_y  max_x    min_f   min_t     max_f  \
# 0       1  unknown      4   1650     94   1654   62.500  52.832  1468.750
# 1       2  unknown      6    423     60    427   93.750  13.568   937.500
# 2       3  unknown      8   1782     28   1794  125.000  57.056   437.500
# 3       7  unknown     14   1845     27   1850  218.750  59.072   421.875
# 4      12  unknown     20   1029     32   1046  312.500  32.960   500.000
# 5      13  unknown     21   1369     39   1374  328.125  43.840   609.375
# 6      14  unknown     21   1379     36   1387  328.125  44.160   562.500
# 7      15  unknown     21   1445     33   1451  328.125  46.272   515.625
#
#     max_t
# 0  52.960
# 1  13.696
# 2  57.440
# 3  59.232
# 4  33.504
# 5  44.000
# 6  44.416
# 7  46.464
# Number of features found in /mnt/d/Aqoustics/UMAP/ind_R6_20220919_074200.WAV: 8
# Finished processing file: /mnt/d/Aqoustics/UMAP/ind_R6_20220919_074200.WAV
# Processing file: /mnt/d/Aqoustics/UMAP/ind_R6_20220920_020800.WAV
#   labelID    label  min_y  min_x  max_y  max_x     min_f   min_t     max_f  \
# 0       1  unknown      4    816     47    820    62.500  26.144   734.375
# 1       6  unknown      5   1140     40   1148    78.125  36.512   625.000
# 2      11  unknown      6   1596     56   1599    93.750  51.104   875.000
# 7      17  unknown     18    751     32    757   281.250  24.064   500.000
# 9      23  unknown     65   1140    116   1143  1015.625  36.512  1812.500
#
#     max_t
# 0  26.272
# 1  36.768
# 2  51.200
# 7  24.256
# 9  36.608
# Number of features found in /mnt/d/Aqoustics/UMAP/ind_R6_20220920_020800.WAV: 5
# Finished processing file: /mnt/d/Aqoustics/UMAP/ind_R6_20220920_020800.WAV
# Processing file: /mnt/d/Aqoustics/UMAP/ind_R6_20220921_055000.WAV
#   labelID    label  min_y  min_x  max_y  max_x   min_f   min_t     max_f  \
# 0       1  unknown      6    408     30    429   93.75  13.088   468.750
# 1       2  unknown      6   1051    113   1055   93.75  33.664  1765.625
# 2       3  unknown      6   1578     89   1582   93.75  50.528  1390.625
# 4       5  unknown     10     83     48     89  156.25   2.688   750.000
# 5       7  unknown     12    431     20    438  187.50  13.824   312.500
#
#     max_t
# 0  13.760
# 1  33.792
# 2  50.656
# 4   2.880
# 5  14.048
# Number of features found in /mnt/d/Aqoustics/UMAP/ind_R6_20220921_055000.WAV: 5
# Finished processing file: /mnt/d/Aqoustics/UMAP/ind_R6_20220921_055000.WAV
# Processing file: /mnt/d/Aqoustics/UMAP/ind_R6_20220921_104600.WAV
#   labelID    label  min_y  min_x  max_y  max_x    min_f   min_t     max_f  \
# 0       1  unknown      4   1046     48   1057   62.500  33.504   750.000
# 1       5  unknown     17     14     30     21  265.625   0.480   468.750
# 2       7  unknown     20    579     35    584  312.500  18.560   546.875
# 3       8  unknown     20    865     40    869  312.500  27.712   625.000
# 4      11  unknown     21    890     44    895  328.125  28.512   687.500
# 5      21  unknown     59    890     80    895  921.875  28.512  1250.000
#
#     max_t
# 0  33.856
# 1   0.704
# 2  18.720
# 3  27.840
# 4  28.672
# 5  28.672
# Number of features found in /mnt/d/Aqoustics/UMAP/ind_R6_20220921_104600.WAV: 6
# Finished processing file: /mnt/d/Aqoustics/UMAP/ind_R6_20220921_104600.WAV
# Processing file: /mnt/d/Aqoustics/UMAP/ind_R6_20220921_162400.WAV
#   labelID    label  min_y  min_x  max_y  max_x    min_f   min_t    max_f  \
# 1       2  unknown      9   1565     20   1569  140.625  50.112  312.500
# 2       5  unknown     14    852     29    856  218.750  27.296  453.125
# 3      10  unknown     21     74     39     85  328.125   2.400  609.375
# 4      11  unknown     21    614     37    619  328.125  19.680  578.125
# 5      12  unknown     21    697     33    701  328.125  22.336  515.625
# 6      26  unknown     25    916     37    921  390.625  29.344  578.125
#
#     max_t
# 1  50.240
# 2  27.424
# 3   2.752
# 4  19.840
# 5  22.464
# 6  29.504
# Number of features found in /mnt/d/Aqoustics/UMAP/ind_R6_20220921_162400.WAV: 6
# Finished processing file: /mnt/d/Aqoustics/UMAP/ind_R6_20220921_162400.WAV
# Processing file: /mnt/d/Aqoustics/UMAP/ind_R6_20220921_185000.WAV
#   labelID    label  min_y  min_x  max_y  max_x    min_f   min_t     max_f  \
# 0       1  unknown      4   1233     34   1238   62.500  39.488   531.250
# 1       2  unknown      5   1161     67   1165   78.125  37.184  1046.875
# 4       7  unknown     22      0     36      4  343.750   0.032   562.500
# 5      11  unknown     22    276     39    280  343.750   8.864   609.375
# 6      13  unknown     22   1240     36   1244  343.750  39.712   562.500
# 7      21  unknown     38   1233     87   1238  593.750  39.488  1359.375
#
#     max_t
# 0  39.648
# 1  37.312
# 4   0.160
# 5   8.992
# 6  39.840
# 7  39.648
# Number of features found in /mnt/d/Aqoustics/UMAP/ind_R6_20220921_185000.WAV: 6
# Finished processing file: /mnt/d/Aqoustics/UMAP/ind_R6_20220921_185000.WAV
# Processing file: /mnt/d/Aqoustics/UMAP/ind_R6_20220921_190400.WAV
#    labelID    label  min_y  min_x  max_y  max_x    min_f   min_t     max_f  \
# 0        1  unknown      5   1482     47   1487   78.125  47.456   734.375
# 1        2  unknown      6    382     51    386   93.750  12.256   796.875
# 2        3  unknown      6    550     57    558   93.750  17.632   890.625
# 3        4  unknown      6    569     55    573   93.750  18.240   859.375
# 4        5  unknown      6    585     55    589   93.750  18.752   859.375
# 5        6  unknown      6    627     80    631   93.750  20.096  1250.000
# 6        7  unknown      6    660     63    664   93.750  21.152   984.375
# 7        8  unknown      7   1080     41   1083  109.375  34.592   640.625
# 9       10  unknown     10   1123    121   1125  156.250  35.968  1890.625
# 10      11  unknown     11   1151     45   1156  171.875  36.864   703.125
# 11      20  unknown     61   1152    124   1152  953.125  36.896  1937.500
#
#      max_t
# 0   47.616
# 1   12.384
# 2   17.888
# 3   18.368
# 4   18.880
# 5   20.224
# 6   21.280
# 7   34.688
# 9   36.032
# 10  37.024
# 11  36.896
# Number of features found in /mnt/d/Aqoustics/UMAP/ind_R6_20220921_190400.WAV: 11
# Finished processing file: /mnt/d/Aqoustics/UMAP/ind_R6_20220921_190400.WAV
# Processing file: /mnt/d/Aqoustics/UMAP/ind_R6_20220922_081400.WAV
#   labelID    label  min_y  min_x  max_y  max_x   min_f   min_t     max_f  \
# 0       1  unknown      5     63     64     68  78.125   2.048  1000.000
# 1       2  unknown      5     88     66     93  78.125   2.848  1031.250
# 2       3  unknown      5    287     73    295  78.125   9.216  1140.625
# 4       5  unknown      5   1079     56   1084  78.125  34.560   875.000
# 5       6  unknown      6     98     66    102  93.750   3.168  1031.250
# 6       7  unknown      6   1311     54   1315  93.750  41.984   843.750
# 7       8  unknown      6   1783     48   1785  93.750  57.088   750.000
#
#     max_t
# 0   2.208
# 1   3.008
# 2   9.472
# 4  34.720
# 5   3.296
# 6  42.112
# 7  57.152
# Number of features found in /mnt/d/Aqoustics/UMAP/ind_R6_20220922_081400.WAV: 7
# Finished processing file: /mnt/d/Aqoustics/UMAP/ind_R6_20220922_081400.WAV
# Processing file: /mnt/d/Aqoustics/UMAP/ind_R6_20220922_192000.WAV
#    labelID    label  min_y  min_x  max_y  max_x     min_f   min_t     max_f  \
# 0        5  unknown     10   1093     56   1099   156.250  35.008   875.000
# 1        6  unknown     10   1217     32   1223   156.250  38.976   500.000
# 2        7  unknown     10   1521     29   1528   156.250  48.704   453.125
# 3       10  unknown     12   1174     29   1179   187.500  37.600   453.125
# 4       12  unknown     12   1591     28   1596   187.500  50.944   437.500
# 5       14  unknown     13   1629     27   1635   203.125  52.160   421.875
# 6       15  unknown     14    479     24    486   218.750  15.360   375.000
# 7       16  unknown     14    516     29    520   218.750  16.544   453.125
# 8       17  unknown     15    894     30    898   234.375  28.640   468.750
# 9       19  unknown     15   1530     29   1539   234.375  48.992   453.125
# 10      22  unknown     16   1152     29   1159   250.000  36.896   453.125
# 11      26  unknown     18   1000     28   1006   281.250  32.032   437.500
# 12      27  unknown     18   1076     27   1082   281.250  34.464   421.875
# 13      28  unknown     18   1139     28   1145   281.250  36.480   437.500
# 14      29  unknown     19    818     36    824   296.875  26.208   562.500
# 15      30  unknown     19    864     34    874   296.875  27.680   531.250
# 16      34  unknown     21    804     34    810   328.125  25.760   531.250
# 17      40  unknown     22   1285     30   1291   343.750  41.152   468.750
# 18      41  unknown     22   1643     30   1652   343.750  52.608   468.750
# 19      56  unknown     50      7     68      9   781.250   0.256  1062.500
# 20      58  unknown     73      7    101      9  1140.625   0.256  1578.125
#
#      max_t
# 0   35.200
# 1   39.168
# 2   48.928
# 3   37.760
# 4   51.104
# 5   52.352
# 6   15.584
# 7   16.672
# 8   28.768
# 9   49.280
# 10  37.120
# 11  32.224
# 12  34.656
# 13  36.672
# 14  26.400
# 15  28.000
# 16  25.952
# 17  41.344
# 18  52.896
# 19   0.320
# 20   0.320
# Number of features found in /mnt/d/Aqoustics/UMAP/ind_R6_20220922_192000.WAV: 21
# Finished processing file: /mnt/d/Aqoustics/UMAP/ind_R6_20220922_192000.WAV
# CSV saved to /mnt/d/Aqoustics/UMAP/output/surfperch_feature_embeddings.csv
# Total number of features extracted from all files: 8218
# Total processing time: 143.25 seconds
